# %%
def homework(a, b):
    #function that manipulates a and b
    c = a + b
    d = a - b
    print(str(a+b = ) + 
    print(a-b)
    print(a*b)
# Out:
#   File "<ipython-input-4-445706b25ade>", line 2
#     print(a+b) if (a+b) == 0:
#                             ^
# SyntaxError: invalid syntax

# %%
homework(2,3)
# Out:
# 5
# -1
# 6
