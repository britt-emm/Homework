# %%
num = [1,3,1,2,5,4,3,2]

# %%
def remove_duplicate(some_list):
    new_list = []
    new_list.append(x)
    return new_list

# %%
remove_duplicate(num)
# Out:
# [1, 3, 1, 2, 5, 4, 3, 2]

# %%
other = [13125432]
