# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager


executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome',**executable_path, headless=False)
url = 'http://dndbeyond.com/classes'
browser.visit(url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [/Users/brittanyminor/.wdm/drivers/chromedriver/mac64/92.0.4515.43/chromedriver] found in cache

# %%
soup = bs(browser.html, 'html.parser')
all_classes = soup.find_all('h3', class_='listing-card__title')


dnd_dict = {'class': []}
for cls in all_classes:
    dnd_class = cls.text.strip()
    dnd_dict['class'].append(dnd_class)
print(dnd_dict)

dnd_df = pd.DataFrame(dnd_dict)
dnd_df
# Out:
# {'class': ['Barbarian', 'Bard', 'Cleric', 'Druid', 'Fighter', 'Monk', 'Paladin', 'Ranger', 'Rogue', 'Sorcerer', 'Warlock', 'Wizard', 'Artificer', 'Blood Hunter']}
#            class
# 0      Barbarian
# 1           Bard
# 2         Cleric
# 3          Druid
# 4        Fighter
# 5           Monk
# 6        Paladin
# 7         Ranger
# 8          Rogue
# 9       Sorcerer
# 10       Warlock
# 11        Wizard
# 12     Artificer
# 13  Blood Hunter

# %% [markdown]
# #### 2 Repeat step 1 but now follow the links to get the paragraphs
#
# I had trouble getting the follow links to work so I stopped with 1.

# %%
soup = bs(browser.html, 'html.parser')
all_classes = soup.find_all('h3', class_='listing-card__title')


dnd_dict = {'class': []}
for cls in all_classes:
    dnd_class = cls.text.strip()
    dnd_dict['class'].append(dnd_class)
print(dnd_dict)

dnd_df = pd.DataFrame(dnd_dict)
dnd_df

# %%
browser.links.find_by_partial_text('/classes/').click()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/miniconda3/lib/python3.8/site-packages/splinter/element_list.py in __getitem__(self, index)
#      41         try:
# ---> 42             return self._container[index]
#      43         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# <ipython-input-18-c7a18da4aa71> in <module>
# ----> 1 browser.links.find_by_partial_text('/classes/').click()
#
# ~/opt/miniconda3/lib/python3.8/site-packages/splinter/element_list.py in __getattr__(self, name)
#      74     def __getattr__(self, name):
#      75         try:
# ---> 76             return getattr(self.first, name)
#      77         except AttributeError:
#      78             try:
#
# ~/opt/miniconda3/lib/python3.8/site-packages/splinter/element_list.py in first(self)
#      55             >>> assert element_list[0] == element_list.first
#      56         """
# ---> 57         return self[0]
#      58
#      59     @property
#
# ~/opt/miniconda3/lib/python3.8/site-packages/splinter/element_list.py in __getitem__(self, index)
#      42             return self._container[index]
#      43         except IndexError:
# ---> 44             raise ElementDoesNotExist(
#      45                 u'no elements could be found with {0} "{1}"'.format(
#      46                     self.find_by, self.query
#
# ElementDoesNotExist: no elements could be found with link by partial text "/classes/"
